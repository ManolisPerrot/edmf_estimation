# %%
from juliacall import Main as jl
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

###################################################
plt.rcParams['text.usetex'] = True
plt.rcParams.update({'font.size': 25})
plt.rcParams.update({'figure.facecolor': 'white'})
plt.rcParams.update({'savefig.facecolor': 'white'})
###########################################


# colors
blue, orange, magenta, grey, green = '#0db4c3', '#eea021', '#ff0364', '#606172', '#3fb532'

# ===========================================================================


#long to run???
jl.seval("""using SequentialMeasureTransport""")
jl.seval("""import SequentialMeasureTransport as SMT""")
jl.seval("""using Distributions""")
jl.seval("""using PythonCall""")

# %%
sampler_name = 'sampler_likelihood2_N2000_L2_phi50.jld2'
print('Load sampler and sample')
jl.seval(f"""sampler = SMT.load_sampler("{sampler_name}")""")
#jl.seval("""sample = rand(sampler, 10000) #""")
jl.seval("""pdf(sampler,zeros(5))""")
# Out:
# Load sampler and sample
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[2], line 5
#       3 jl.seval(f"""sampler = SMT.load_sampler("{sampler_name}")""")
#       4 #jl.seval("""sample = rand(sampler, 10000) #""")
# ----> 5 jl.seval("""pdf(sampler,0:5)""")
#
# File ~/.julia/packages/PythonCall/bb3ax/src/JlWrap/module.jl:25, in seval(self, expr)
#      23         return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlmodule_dir)))
#      24     def seval(self, expr):
# ---> 25         return self._jl_callmethod($(pyjl_methodnum(pyjlmodule_seval)), expr)
#      26 """, @__FILE__(), "exec"), jl.__dict__)
#      27 pycopy!(pyjlmoduletype, jl.ModuleValue)
#
# JuliaError: UndefVarError: `NotImplementedError` not defined
# Stacktrace:
#  [1] pdf(sampler::SequentialMeasureTransport.CondSampler{5, 0, Float64, SequentialMeasureTransport.ReferenceMaps.ScalingReference{5, 0, Float64}, SequentialMeasureTransport.ReferenceMaps.ScalingReference{5, 0, Float64}}, x::UnitRange{Int64})
#    @ SequentialMeasureTransport ~/.julia/packages/SequentialMeasureTransport/KkSUi/src/Samplers/sampler.jl:223
#  [2] top-level scope
#    @ none:1
#  [3] eval
#    @ ./boot.jl:385 [inlined]
#  [4] eval
#    @ ./Base.jl:88 [inlined]
#  [5] pyjlmodule_seval(self::Module, expr::Py)
#    @ PythonCall.JlWrap ~/.julia/packages/PythonCall/bb3ax/src/JlWrap/module.jl:13
#  [6] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall.JlWrap ~/.julia/packages/PythonCall/bb3ax/src/JlWrap/base.jl:66
#  [7] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.JlWrap.Cjl ~/.julia/packages/PythonCall/bb3ax/src/JlWrap/C.jl:63

# %%
jl.seval("""pdf(sampler,zeros(5))""")
# Out:
# 0.0

# %%
sampler_name = 'sampler_likelihood2_N2000_L2_phi50.jld2'
print('Load sampler and sample')
jl.seval(f"""sampler = SMT.load_sampler("{sampler_name}")""")
jl.seval("""sample = rand(sampler, 10000) #""")

#convert to numpy
sample_py = np.array(jl.seval(""" Py(hcat(sample...)) """))


#convert to Panda dataframe
df = pd.DataFrame(sample_py.T, columns=[r'$C_E$', r'$C_D$', r'$b^\prime$', r'$\delta_0$', r'$a$'])

g = sns.PairGrid(df, diag_sharey=False, corner=True)
#g.map_upper(sns.jointplot)
#g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, color=blue)
#g.map_lower(sns.scatterplot)

g.map_diag(sns.histplot, kde=True, color=orange )
# Out:
# Load sampler and sample

# %%
sampler_name = 'sampler_likelihood2_N2000_L2_phi50.jld2'
print('Load sampler and sample')
jl.seval(f"""sampler = SMT.load_sampler("{sampler_name}")""")
jl.seval("""sample = rand(sampler, 10000) #""")

#convert to numpy
sample_py = np.array(jl.seval(""" Py(hcat(sample...)) """))


#convert to Panda dataframe
df = pd.DataFrame(sample_py.T, columns=[r'$C_E$', r'$C_D$', r'$b^\prime$', r'$\delta_0$', r'$a$'])

g = sns.PairGrid(df, diag_sharey=False, corner=True)
#g.map_upper(sns.jointplot)
#g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, color=blue)
#g.map_lower(sns.scatterplot)

g.map_diag(sns.histplot, kde=True, color=orange )
# Out:
# Load sampler and sample

# %%
sampler_name = 'sampler_likelihood2_N2000_L2_phi50.jld2'
print('Load sampler and sample')
jl.seval(f"""sampler = SMT.load_sampler("{sampler_name}")""")
jl.seval("""sample = rand(sampler, 1000) #""")

#convert to numpy
sample_py = np.array(jl.seval(""" Py(hcat(sample...)) """))


#convert to Panda dataframe
df = pd.DataFrame(sample_py.T, columns=[r'$C_E$', r'$C_D$', r'$b^\prime$', r'$\delta_0$', r'$a$'])

g = sns.PairGrid(df, diag_sharey=False, corner=True)
#g.map_upper(sns.jointplot)
#g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, color=blue)
#g.map_lower(sns.scatterplot)

g.map_diag(sns.histplot, kde=True, color=orange )
# Out:
# Load sampler and sample

# %%
sampler_name = 'sampler_likelihood2_N2000_L4_phi50.jld2'
print('Load sampler and sample')
jl.seval(f"""sampler = SMT.load_sampler("{sampler_name}")""")
jl.seval("""sample = rand(sampler, 100) #""")

#convert to numpy
sample_py = np.array(jl.seval(""" Py(hcat(sample...)) """))


#convert to Panda dataframe
df = pd.DataFrame(sample_py.T, columns=[r'$C_E$', r'$C_D$', r'$b^\prime$', r'$\delta_0$', r'$a$'])

g = sns.PairGrid(df, diag_sharey=False, corner=True)
#g.map_upper(sns.jointplot)
#g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, color=blue)
#g.map_lower(sns.scatterplot)

g.map_diag(sns.histplot, kde=True, color=orange )
# Out:
# Load sampler and sample

# %%
8491/60/60
# Out:
# 2.358611111111111
