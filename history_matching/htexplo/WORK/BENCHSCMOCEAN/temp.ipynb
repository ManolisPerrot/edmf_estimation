# %%
###########################################
# Imports
###########################################
import sys #to put the SCM into the PYTHONPATH
sys.path.append('../../../../edmf_ocean/library/F2PY/')
sys.path.append('../../../../')
from sys import exit
import numpy as np
import matplotlib.pyplot as plt
# from scm_oce import direct_scmoce
#from scipy.io import netcdf
from netCDF4 import Dataset
from scm_class import SCM
from scipy.interpolate import interp1d
import scipy as sci
import netCDF4 as nc
import xarray as xr
#from cost_function_HIRES10 import cost_function
import itertools
import scipy.stats.qmc as qmc
from multiprocessing import Pool
import pickle
from case_configs import case_params, default_params
from concurrent.futures import ProcessPoolExecutor

import time as TIME
start = TIME.time() #monitor duration of execution 

debug=True
if debug:
    # Interactive testing: Set default values for `waven` and `cas`
    waven = "1"
    cas = "FC500"
else:
    # If running as a script, capture arguments
    #----- Input arguments
    waven = sys.argv[1]  # First argument   
    cas = sys.argv[2]    # Second argument  

print("WAVEN:", waven)
print("cas:", cas)
###########################################
# Initialize an empty dictionary
data = {}
dir = f'../../WORK/BENCHSCMOCEAN/WAVE{waven}/'
param_file =f'Par1D_Wave{waven}.asc'
# Initialize an empty dictionary
data_dict = {}

# Open the file and read lines
with open(dir+param_file, "r") as file:
    # Read the first line (header) and strip quotes
    header_line = file.readline().strip()
    headers = [header.strip('"') for header in header_line.split()]
    
    # Store the headers as the first entry in the dictionary
    data_dict["t_IDs"] = headers[1:]  # Skip the first header entry, "t_IDs"
    
    # Read the remaining lines for data entries
    for line in file:
        # Split line into identifier and data values
        parts = line.strip().split()
        key = parts[0].strip('"')  # First item is the identifier, without quotes
        values = [float(value) for value in parts[1:]]  # Convert remaining values to floats
        
        # Add to dictionary
        data_dict[key] = values


#--------------------------------------------

def scm_model(X, case, run_id):
    # ====================================Run the SCM cases=======================================
    params = default_params.copy()  # Create a copy of default_params
    params.update(case_params[case])  # Update with the specific case hyperparameters in case_params[case]
    params.update({'write_netcdf': True,'output_filename': dir+f'{case}/'+run_id+'.nc'})  
    # unpack X values in the form of a dictionary. 
    params_to_estimate = { key: X[i] for i, key in enumerate(data_dict["t_IDs"])} 
    params_to_estimate['vp_c'] = params_to_estimate['up_c']
    params.update(params_to_estimate) # Update with the parameters to estimate

    scm = SCM(**params)
    scm.run_direct()            # Run the SCM 
cas=case
# Define the task for each run
def run_scm_model(run_id):
    if run_id != 't_IDs':
        print(f"Running {case} for {run_id}")
        scm_model(X=data_dict[run_id], case=case, run_id=run_id)

# Run in parallel
with ProcessPoolExecutor() as executor:
    # Submit all tasks to the executor
    executor.map(run_scm_model, data_dict.keys())
# Out:
# WAVEN: 1
# cas: FC500
# Running FC500 for SCM-1-002Running FC500 for SCM-1-001Running FC500 for SCM-1-004Running FC500 for SCM-1-005Running FC500 for SCM-1-003Running FC500 for SCM-1-006Running FC500 for SCM-1-008
# Running FC500 for SCM-1-007
#
#
#
#
#
#
# Running FC500 for SCM-1-009
# Running FC500 for SCM-1-010
# Running FC500 for SCM-1-011
# Running FC500 for SCM-1-012
# Running FC500 for SCM-1-013
# Running FC500 for SCM-1-014
# Running FC500 for SCM-1-015Running FC500 for SCM-1-016
#
# Running FC500 for SCM-1-017
# Running FC500 for SCM-1-018
# Running FC500 for SCM-1-019
# Running FC500 for SCM-1-020
# Running FC500 for SCM-1-021
# Running FC500 for SCM-1-022Running FC500 for SCM-1-023
#
# Running FC500 for SCM-1-024
# Running FC500 for SCM-1-025
# Running FC500 for SCM-1-026
# Running FC500 for SCM-1-027
# Running FC500 for SCM-1-028
# Running FC500 for SCM-1-029
# Running FC500 for SCM-1-030
# Running FC500 for SCM-1-031
# Running FC500 for SCM-1-032
# Running FC500 for SCM-1-033
# Running FC500 for SCM-1-034
# Running FC500 for SCM-1-035
# Running FC500 for SCM-1-036
# Running FC500 for SCM-1-037
# Running FC500 for SCM-1-038
# Running FC500 for SCM-1-039
# Running FC500 for SCM-1-040
# Running FC500 for SCM-1-041
# Running FC500 for SCM-1-042
# Running FC500 for SCM-1-043Running FC500 for SCM-1-044
#
# Running FC500 for SCM-1-045
# Running FC500 for SCM-1-046
